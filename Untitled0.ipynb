# %%
import pandas as pd
import numpy as np

df = pd.read_csv('train.csv')
df.head()
# Out:
#     timestamp     open     high      low    close   volume  \
# 0  1525471260  0.90120  0.90130  0.90120  0.90130   134.98
# 1  1525471320  0.90185  0.90195  0.90185  0.90195  1070.54
# 2  1525471380  0.90140  0.90140  0.90139  0.90139  2293.06
# 3  1525471440  0.90139  0.90140  0.90138  0.90139  6850.59
# 4  1525471500  0.90139  0.90139  0.90130  0.90130   832.30
#
#    quote_asset_volume  number_of_trades  taker_buy_base_volume  \
# 0          121.646459               4.0                 125.08
# 1          965.505313              12.0                 879.94
# 2         2066.963991               5.0                   0.00
# 3         6175.000909              19.0                1786.30
# 4          750.222624               3.0                 784.82
#
#    taker_buy_quote_volume  target
# 0              112.723589     1.0
# 1              793.612703     0.0
# 2                0.000000     0.0
# 3             1610.149485     0.0
# 4              707.428900     0.0

# %%
# transform timestamp to datetime
df['timestamp'] = pd.to_datetime(df['timestamp'], unit='s')
# filter data after 2022-01-01
df = df[df['timestamp'] > '2022-01-01']
# Reset the index of the DataFrame
df.reset_index(drop=True, inplace=True)

# %%
# Display basic information
print("Dataset Basic Information:")
print(df.info())

# Check for missing values
print("\nMissing Values Statistics:")
display(df.isnull().sum())
# Out:
# Dataset Basic Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2122438 entries, 0 to 2122437
# Data columns (total 11 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   timestamp               datetime64[ns]
#  1   open                    float64
#  2   high                    float64
#  3   low                     float64
#  4   close                   float64
#  5   volume                  float64
#  6   quote_asset_volume      float64
#  7   number_of_trades        float64
#  8   taker_buy_base_volume   float64
#  9   taker_buy_quote_volume  float64
#  10  target                  float64
# dtypes: datetime64[ns](1), float64(10)
# memory usage: 178.1 MB
# None
#
# Missing Values Statistics:
# timestamp                 0
# open                      0
# high                      0
# low                       0
# close                     0
# volume                    0
# quote_asset_volume        0
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# The distribution of the target variable -> I will do down-sampling after EDA
target_dist = df['target'].value_counts(normalize=True)
print("Target Variable Distribution:")
display(target_dist)

plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='target')
plt.title("Target Variable Distribution")
plt.show()
# Out:
# Target Variable Distribution:
# target
# 0.0    0.524215
# 1.0    0.475785
# Name: proportion, dtype: float64

# %%
# Price trend
plt.figure(figsize=(15, 8))
plt.plot(df['timestamp'], df['close'])
plt.title('Closing Price Over Time')
plt.xlabel('Time')
plt.ylabel('Price')
plt.xticks(rotation=45)
plt.show()

# %%
from statsmodels.tsa.stattools import adfuller, kpss

def test_stationarity(series, name):
    adf_result = adfuller(series.dropna())
    kpss_result = kpss(series.dropna(), regression='c', nlags='legacy')
    print(f"Feature: {name}")
    print(f"ADF p-value: {adf_result[1]} {'(Stationary)' if adf_result[1] < 0.05 else '(Non-stationary)'}")
    print(f"KPSS p-value: {kpss_result[1]} {'(Stationary)' if kpss_result[1] > 0.05 else '(Non-stationary)'}")

# low
# test_stationarity(df["close"], "close")

# %%
import numpy as np

df['diff_close'] = df['close'].diff()
df.dropna(inplace=True)

# test_stationarity(df["diff_close"], "diff_close")

# %%
plt.figure(figsize=(15, 8))
plt.plot(df['timestamp'], df['diff_close'], label='Differenced')
plt.legend()
plt.title('Differenced Price')
plt.show()

# %%
def calculate_macd(df, fast_period, slow_period, signal_period):
    """
    MACD Metrics Calculation
    """
    ema_fast = df['close'].ewm(span=fast_period, adjust=False).mean()
    ema_slow = df['close'].ewm(span=slow_period, adjust=False).mean()
    macd = ema_fast - ema_slow
    signal = macd.ewm(span=signal_period, adjust=False).mean()
    macd_hist = macd - signal
    return macd, signal, macd_hist

# MACD
macd_parameters = [
    {'fast': 6, 'slow': 13, 'signal': 5},
    {'fast': 9, 'slow': 20, 'signal': 7},
    {'fast': 12, 'slow': 26, 'signal': 9},
    {'fast': 3, 'slow': 10, 'signal': 4},
    {'fast': 5, 'slow': 15, 'signal': 5},
    {'fast': 7, 'slow': 17, 'signal': 6},
    {'fast': 8, 'slow': 18, 'signal': 7},
    {'fast': 10, 'slow': 25, 'signal': 6},
    {'fast': 4, 'slow': 12, 'signal': 3},
    {'fast': 11, 'slow': 22, 'signal': 8}
]

df = df.sort_values('timestamp').reset_index(drop=True)

for params in macd_parameters:
    fast = params['fast']
    slow = params['slow']
    signal = params['signal']

    # Calculate MACD
    macd, signal_line, macd_hist = calculate_macd(df, fast, slow, signal)
    
    # add to DataFrame
    df[f'MACD_{fast}_{slow}_{signal}'] = macd
    df[f'Signal_{fast}_{slow}_{signal}'] = signal_line
    df[f'MACD_Hist_{fast}_{slow}_{signal}'] = macd_hist


# RSI
def compute_rsi(series, window):
    delta = series.diff()
    gain = (delta.where(delta > 0, 0)).rolling(window=window).mean()
    loss = (-delta.where(delta < 0, 0)).rolling(window=window).mean()
    rs = gain / loss
    rsi = 100 - (100 / (1 + rs))
    return rsi

# Define RSI window sizes to try
rsi_windows = [5, 7, 14, 21]

# Calculate RSI for each window size
for window in rsi_windows:
    df[f'rsi_{window}'] = compute_rsi(df['close'], window=window)


# Define SMA & volume MA window sizes to try
ma_windows = [3, 5, 7, 10, 14, 20]

for window in ma_windows:
    df[f'sma_{window}'] = df['close'].rolling(window=window, min_periods=1).mean()
    df[f'volume_ma_{window}'] = df['volume'].rolling(window=window).mean()
    df[f'volume_ma_{window}'] = df['volume'].rolling(window=window).mean()

# price range and percent change
df['price_range'] = df['high'] - df['low']
df['percent_change'] = (df['close'] - df['open']) / df['open']


# lag features
lag_periods = [1, 2, 3, 4, 5]

features_to_lag = ['close']
for feature in features_to_lag:
    for lag in lag_periods:
        df[f'{feature}_lag_{lag}'] = df[feature].shift(lag)

features_to_lag_diff = ['diff_close']
for feature in features_to_lag_diff:
    for lag in lag_periods:
        df[f'{feature}_lag_{lag}'] = df[feature].shift(lag)

# money flow index
df['money_flow_multiplier'] = ((df['close'] - df['low']) - (df['high'] - df['close'])) / (df['high'] - df['low'])
df['money_flow_volume'] = df['money_flow_multiplier'] * df['volume']

df.dropna(inplace=True)

# %%
split_ratio = 0.8
split_point = int(len(df) * split_ratio)

train = df.iloc[:split_point].reset_index(drop=True)
test = df.iloc[split_point:].reset_index(drop=True)

# %%
import math

numeric_features = train.select_dtypes(include=[np.number]).columns.tolist()
numeric_features.remove('target')

cols = 5

rows = math.ceil(len(numeric_features) / cols)

plt.figure(figsize=(cols * 4, rows * 4))

for idx, feature in enumerate(numeric_features):
    plt.subplot(rows, cols, idx + 1)
    sns.boxplot(x=train[feature])
    plt.title(f'{feature} Before Removing Outliers')
    plt.xticks(rotation=45)

for idx in range(len(numeric_features), rows * cols):
    plt.subplot(rows, cols, idx + 1).axis('off')

plt.tight_layout()
plt.show()

# %%
from scipy.stats import norm

plt.figure(figsize=(10, 6))
sns.histplot(train['diff_close'], kde=True, color='red', bins=30, stat="density", label="Density")

mean = train['diff_close'].mean()
std = train['diff_close'].std()
x = np.linspace(train['diff_close'].min(), train['diff_close'].max(), 100)
y = norm.pdf(x, mean, std)
plt.plot(x, y, color='black', label='Normal Distribution')

plt.title('Distribution of Close Diff with Normal Curve')
plt.xlabel('Close Diff')
plt.ylabel('Density')
plt.legend()

plt.show()

# %%
from sklearn.ensemble import IsolationForest

train_original = train.copy()

# 使用 Isolation Forest 檢測異常值
iso_forest = IsolationForest(contamination="auto", random_state=42)
iso_forest.fit(train.drop(columns=['target', 'timestamp']))
outliers = iso_forest.predict(train.drop(columns=['target', 'timestamp']))

# 只保留正常數據
train = train[outliers == 1]
print(f"Number of outliers: {len(outliers)}")
print(f"Number of remaining data points: {len(train)}")
# Out:
# Number of outliers: 1681924
# Number of remaining data points: 1536211

# %%
plt.figure(figsize=(cols * 4, rows * 4))

for idx, feature in enumerate(numeric_features):
    plt.subplot(rows, cols, idx + 1)
    sns.boxplot(x=train[feature])
    plt.title(f'{feature} After Removing Outliers')
    plt.xticks(rotation=45)

for idx in range(len(numeric_features), rows * cols):
    plt.subplot(rows, cols, idx + 1).axis('off')

plt.tight_layout()
plt.show()

# %%
from scipy.stats import norm

plt.figure(figsize=(10, 6))
sns.histplot(train['diff_close'], kde=True, color='red', bins=30, stat="density", label="Density")

mean = train['diff_close'].mean()
std = train['diff_close'].std()
x = np.linspace(train['diff_close'].min(), train['diff_close'].max(), 100)
y = norm.pdf(x, mean, std)
plt.plot(x, y, color='black', label='Normal Distribution')

plt.title('Distribution of Close Diff with Normal Curve')
plt.xlabel('Close Diff')
plt.ylabel('Density')
plt.legend()

plt.show()

# %%
train.head()
# Out:
#              timestamp     open     high      low    close    volume  \
# 5  2018-05-04 22:27:00  0.89787  0.89790  0.89787  0.89787  10914.10
# 8  2018-05-04 22:30:00  0.89575  0.89782  0.89571  0.89571    446.13
# 10 2018-05-04 22:32:00  0.89787  0.89787  0.89572  0.89572   1318.45
# 11 2018-05-04 22:33:00  0.89572  0.89572  0.89570  0.89570   1604.75
# 12 2018-05-04 22:34:00  0.89568  0.89568  0.89445  0.89445      6.92
#
#     quote_asset_volume  number_of_trades  taker_buy_base_volume  \
# 5          9799.465432               8.0                8247.57
# 8           400.511026               7.0                 438.28
# 10         1183.339181               5.0                   0.00
# 11         1437.376947               9.0                   0.00
# 12            6.197552               3.0                   6.47
#
#     taker_buy_quote_volume  ...  close_lag_3  close_lag_4  close_lag_5  \
# 5              7405.268141  ...      0.89535      0.89778      0.89790
# ...

# %%
from sklearn.utils import resample

positive = train[train['target'] == 1]
negative = train[train['target'] == 0]

print(f"Number of positive samples: {len(positive)}")
print(f"Number of negative samples: {len(negative)}")

negative_downsampled = resample(negative,
                                replace=False,
                                n_samples=len(positive),
                                random_state=42)

train_downsampled = pd.concat([positive, negative_downsampled])

print(f"Number of downsampled negative samples: {len(negative_downsampled)}")
# Out:
# Number of positive samples: 733159
# Number of negative samples: 803052
# Number of downsampled negative samples: 733159

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# The distribution of the target variable -> I will do down-sampling after EDA
target_dist = train_downsampled['target'].value_counts(normalize=True)
print("Target Variable Distribution:")
display(target_dist)

plt.figure(figsize=(10, 6))
sns.countplot(data=train_downsampled, x='target')
plt.title("Target Variable Distribution")
plt.show()
# Out:
# Target Variable Distribution:
# target
# 1.0    0.5
# 0.0    0.5
# Name: proportion, dtype: float64

# %%
X_train = train_downsampled.drop(columns=['target', 'timestamp'])
y_train = train_downsampled['target']

X_test = test.drop(columns=['target', 'timestamp'])
y_test = test['target']

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix, roc_curve, roc_auc_score, f1_score
import matplotlib.pyplot as plt

model_tree = DecisionTreeClassifier(
    random_state=42,
    max_depth=5,
    min_samples_split=10,
    min_samples_leaf=5,
    max_features='sqrt'
)

model_tree.fit(X_train, y_train)

y_pred_tree = model_tree.predict(X_test)
y_pred_tree_prob = model_tree.predict_proba(X_test)[:, 1]

cnf_matrix_tree = confusion_matrix(y_test, y_pred_tree)
print("Confusion Matrix:")
print(cnf_matrix_tree)

f1_macro = f1_score(y_test, y_pred_tree, average='macro')
print("F1 Score (Macro):", f1_macro)


tree_fpr, tree_tpr, _ = roc_curve(y_test, y_pred_tree_prob)
auc_tree = roc_auc_score(y_test, y_pred_tree_prob)

plt.figure()
plt.plot(tree_fpr, tree_tpr, label=f'Decision Tree AUC {auc_tree:.3f}')
plt.plot([0, 1], [0, 1], 'r--')
plt.legend(loc=4)
plt.grid()
plt.show()
# Out:
# Confusion Matrix:
# [[ 47353 176063]
#  [ 39041 158024]]
# F1 Score (Macro): 0.45035711563344333

# %%
feature_names = X_train.columns

importances = model_tree.feature_importances_

feature_importance_df = pd.DataFrame({
    'Feature': feature_names,
    'Importance': importances
})

feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)

print("Feature Importance:")
print(feature_importance_df)

plt.figure(figsize=(10, 18))
plt.barh(feature_importance_df['Feature'], feature_importance_df['Importance'])
plt.xlabel('Feature Importance')
plt.ylabel('Features')
plt.title('Decision Tree Feature Importances')
plt.gca().invert_yaxis()  
plt.show()
# Out:
# Feature Importance:
#                   Feature  Importance
# 68  money_flow_multiplier    0.345590
# 42                 rsi_14    0.134370
# 9              diff_close    0.096796
# 45            volume_ma_3    0.082981
# 69      money_flow_volume    0.078571
# ..                    ...         ...
# 37           MACD_11_22_8    0.000000
# 38         Signal_11_22_8    0.000000
# 39      MACD_Hist_11_22_8    0.000000
# 11          Signal_6_13_5    0.000000
# 10            MACD_6_13_5    0.000000
#
# [70 rows x 2 columns]

# %%
X_train = X_train[feature_importance_df['Feature'][:25].values]
X_test = X_test[feature_importance_df['Feature'][:25].values]

# %%
import lightgbm as lgb
from sklearn.model_selection import RandomizedSearchCV, StratifiedKFold
from sklearn.metrics import f1_score, make_scorer

param_dist = {
    'num_leaves': [31, 50, 70],
    'max_depth': [5, 10, 15],
    'learning_rate': [0.01, 0.05, 0.1],
    'n_estimators': [100, 200, 300],
    'min_child_samples': [20, 30, 40],
    'subsample': [0.6, 0.8, 1.0],
    'colsample_bytree': [0.6, 0.8, 1.0]
}

model_lgb = lgb.LGBMClassifier(
    objective='binary',
    random_state=42,
    class_weight='balanced'
)

cv = StratifiedKFold(n_splits=4, shuffle=True, random_state=42)

f1_macro = make_scorer(f1_score, average='macro')

random_search = RandomizedSearchCV(
    estimator=model_lgb,
    param_distributions=param_dist,
    n_iter=20,
    scoring=f1_macro,
    cv=cv,
    verbose=1,
    random_state=42,
    n_jobs=-1
)

# 执行随机搜索
random_search.fit(X_train, y_train)

print("Best params:", random_search.best_params_)
print("Best F1 Score (Macro):", random_search.best_score_)


best_model = random_search.best_estimator_
best_model.fit(X_train, y_train)

y_pred = best_model.predict(X_test)
y_pred_prob = best_model.predict_proba(X_test)[:, 1]

from sklearn.metrics import confusion_matrix, roc_auc_score, roc_curve
import matplotlib.pyplot as plt

# 混淆矩阵
cnf_matrix = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(cnf_matrix)

# F1 Score (Macro)
f1_macro_score = f1_score(y_test, y_pred, average='macro')
print("F1 Score (Macro):", f1_macro_score)

# ROC 曲线和 AUC
fpr, tpr, _ = roc_curve(y_test, y_pred_prob)
auc_score = roc_auc_score(y_test, y_pred_prob)

plt.figure()
plt.plot(fpr, tpr, label=f'LightGBM AUC {auc_score:.3f}')
plt.plot([0, 1], [0, 1], 'r--')
plt.legend(loc=4)
plt.grid()
plt.show()
# Out:
# Fitting 4 folds for each of 20 candidates, totalling 80 fits
# [LightGBM] [Info] Number of positive: 549869, number of negative: 549870
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.184503 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Number of positive: 549869, number of negative: 549869
# [LightGBM] [Info] Total Bins 6375
# [LightGBM] [Info] Number of data points in the train set: 1099739, number of used features: 25
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Info] Start training from score 0.000000
# [LightGBM] [Info] Number of positive: 549869, number of negative: 549869
# [LightGBM] [Info] Number of positive: 549869, number of negative: 549869
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.417924 seconds.
# ...

# %%
# import lightgbm as lgb
# from sklearn.model_selection import train_test_split, TimeSeriesSplit
# from sklearn.metrics import f1_score, classification_report
